# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'Desktop/CF/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/df_ords_clean.csv'

# %%
path2 = r'Desktop/CF/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/df_prods_clean_no_dups.csv'

# %%
path3 = r'Desktop/CF/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/departments_wrangled.csv'

# %%
path4 = r'Desktop/CF/Achievement 4/Instacart Basket Analysis/02 Data/Original Data/orders_products_prior.csv'

# %%
Path_orig =r'Desktop/CF/Achievement 4/Instacart Basket Analysis'

# %%
df_ords = pd.read_csv(os.path.join(path), index_col = False)

# %%
df_prods =pd.read_csv(os.path.join(path2), index_col = False)

# %%
df_dep =pd.read_csv(os.path.join(path3), index_col = False)

# %%
df_ords_prior =pd.read_csv(os.path.join(path4), index_col = False)

# %%
df_ords= df_ords.drop(columns=['Unnamed: 0'])

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#   orders_days_since_order
# 0             First_order
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
pd.merge(df_ords,df_ords_prior, on = ['order_id'], indicator = True)
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           order_hour_of_day orders_days_since_order  product_id  \
# 0                         8             First_order         196
# 1                         8             First_order       14084
# ...

# %%
df_merged_large = df_ords.merge(df_ords_prior, on ='order_id', indicator = True)

# %%
df_merged_large.to_pickle(os.path.join(Path_orig, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %%
df_merged_large
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           order_hour_of_day orders_days_since_order  product_id  \
# 0                         8             First_order         196
# 1                         8             First_order       14084
# ...

# %%
df_merged_large.shape
# Out:
# (32434489, 10)
