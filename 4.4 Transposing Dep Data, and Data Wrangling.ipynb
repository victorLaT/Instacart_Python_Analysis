# %% [markdown]
# # Transposing Dep Data, and Data Wrangling

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'Desktop/CF/Achievement 4/Instacart Basket Analysis/02 Data/Original Data/4.3_orders_products/orders.csv'

# %%
path2 = r'Desktop/CF/Achievement 4/Instacart Basket Analysis/02 Data/Original Data/4.3_orders_products/products.csv'

# %%
path3 =r'Desktop/CF/Achievement 4/Instacart Basket Analysis/02 Data/Original Data/departments.csv'

# %%
path_orig =r'Desktop/CF/Achievement 4/Instacart Basket Analysis'

# %%
df_ords = pd.read_csv(os.path.join(path), index_col = False)

# %%
df_prods = pd.read_csv(os.path.join(path2), index_col = False)

# %%
df_dep = pd.read_csv(os.path.join(path3), index_col = False)

# %%
df_dep
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Changing the frame of Df_dep

# %%
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# ## Changing the Index and Header

# %%
df_dep_T= df_dep.T

# %%
df_dep_T.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
new_header = df_dep_T.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t_new = df_dep_T[1:]

# %%
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# ## Made Df_dep as a Data_dict

# %%
data_dict = df_dep_t_new.to_dict('index')

# %%
df_ords
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
df_ords.info
# Out:
# <bound method DataFrame.info of          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# ...

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %% [markdown]
# ## Renaming the appropriate columns

# %%
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# ...

# %% [markdown]
# # Changing the Data types of the columns( I made a mistake and corrected it on the next assignment)

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')# I changed them all tothe order_id type.

# %%
df_ords['user_id'] = df_ords['order_id'].astype('str')

# %%
df_ords['order_number'] = df_ords['order_id'].astype('str')

# %%
df_ords.describe()
# Out:
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# 25%          1.000000e+00       1.000000e+01            4.000000e+00
# 50%          3.000000e+00       1.300000e+01            7.000000e+00
# 75%          5.000000e+00       1.600000e+01            1.500000e+01
# max          6.000000e+00       2.300000e+01            3.000000e+01

# %%
df_ords.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
df_ords.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
df_ords.head()
# Out:
#   order_id  user_id order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329  2539329      2539329                   2                  8
# 1  2398795  2398795      2398795                   3                  7
# 2   473747   473747       473747                   3                 12
# 3  2254736  2254736      2254736                   4                  7
# 4   431534   431534       431534                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   user_id                 object
#  2   order_number            object
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 156.6+ MB

# %%
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# # Renaming Columns

# %%
df_ords.rename(columns = {'days_since_prior_order' : 'orders_days_since_order'}, inplace = True)

# %%
df_ords
# Out:
#         order_id  user_id order_number  orders_day_of_week  order_hour_of_day  \
# 0        2539329  2539329      2539329                   2                  8
# 1        2398795  2398795      2398795                   3                  7
# 2         473747   473747       473747                   3                 12
# 3        2254736  2254736      2254736                   4                  7
# 4         431534   431534       431534                   4                 15
# ...          ...      ...          ...                 ...                ...
# 3421078  2266710  2266710      2266710                   5                 18
# 3421079  1854736  1854736      1854736                   4                 10
# 3421080   626363   626363       626363                   1                 12
# 3421081  2977660  2977660      2977660                   1                 12
# 3421082   272231   272231       272231                   6                 14
#
#          orders_days_since_order
# ...

# %% [markdown]
# ## Order of day  Value Count

# %%
df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %%
#4. 10:00 Am

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
#5 Produce

# %% [markdown]
# # Creating a subset

# %%
df_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# %%
# breakfast Subset

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
df_dinner_party = df_prods.loc[df_prods['department_id'] .isin([5,7,12,20])]

# %%
df_dinner_party
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
#7650 rows

# %%
df_User1 = df_ords[df_ords['user_id'].isin(['1'])]

# %%
df_User1
# Out:
#         order_id user_id order_number  orders_day_of_week  order_hour_of_day  \
# 1868044        1       1            1                   4                 10
#
#          orders_days_since_order
# 1868044                      9.0

# %%
#from this info we can gather that User_1 ordered on Wednesday at 10:00 Am and its been 9 days since his last order.

# %%
df_ords
# Out:
#         order_id  user_id order_number  orders_day_of_week  order_hour_of_day  \
# 0        2539329  2539329      2539329                   2                  8
# 1        2398795  2398795      2398795                   3                  7
# 2         473747   473747       473747                   3                 12
# 3        2254736  2254736      2254736                   4                  7
# 4         431534   431534       431534                   4                 15
# ...          ...      ...          ...                 ...                ...
# 3421078  2266710  2266710      2266710                   5                 18
# 3421079  1854736  1854736      1854736                   4                 10
# 3421080   626363   626363       626363                   1                 12
# 3421081  2977660  2977660      2977660                   1                 12
# 3421082   272231   272231       272231                   6                 14
#
#          orders_days_since_order
# ...

# %%
df_ords.to_csv(os.path.join(path_orig, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %%
df_dep_t_new.to_csv(os.path.join(path_orig,'02 Data','Prepared Data', 'departments_wrangled.csv'))
