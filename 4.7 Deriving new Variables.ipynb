# %% [markdown]
# # Deriving new Variables

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'Desktop/CF/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_merged.pkl'

# %%
path_orig = r'Desktop/CF/Achievement 4/Instacart Basket Analysis'

# %%
df_ords_prods = pd.read_pickle(os.path.join(path))

# %%
df_ords_prods
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32434207   1320836   202557            17                   2
# 32434208     31526   202557            18                   5
# 32434209    758936   203436             1                   2
# 32434210   2745165   203436             2                   3
# 32434211   3093936   205420             1                   4
#
#           order_hour_of_day orders_days_since_order  product_id  \
# 0                         8             First_order         196
# 1                         7                    15.0         196
# ...

# %%
df = df_ords_prods[:1000000]

# %% [markdown]
# ## User Defined Variable

# %%
def price_label(row):

    if row['prices'] <=5:
        return 'Low-range product'
    elif (row['prices'] >5) and (row['prices'] <=15):
        return 'Mid-range product'
    elif row ['prices'] > 15:
        return 'High ange'
    else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/ys/c00h737n045dn1bcd8vmxlrc0000gn/T/ipykernel_30932/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %% [markdown]
# ## UDV data check

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
df_ords_prods.loc[df_ords_prods['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods.loc[(df_ords_prods['prices'] <= 15) & (df_ords_prods['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods.loc[df_ords_prods['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21890146
# Low-range product     10126384
# High-range product      417682
# Name: count, dtype: int64

# %% [markdown]
# ## Simple for Loop

# %%
for x in range(30, 45):
    print("My age is %d" % (x))
# Out:
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %%
df_ords_prods['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: count, dtype: int64

# %% [markdown]
# ## Adding a column using a for Loop

# %%
result = []
for value in df_ords_prods["orders_day_of_week"]:
    if value ==0:
        result.append("Busiest day")
    elif value ==4:
        result.append("Least busy")
    else:
        result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods['busiest_day'] = result

# %%
df_ords_prods['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: count, dtype: int64

# %%
df_ords_prods
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32434207   1320836   202557            17                   2
# 32434208     31526   202557            18                   5
# 32434209    758936   203436             1                   2
# 32434210   2745165   203436             2                   3
# 32434211   3093936   205420             1                   4
#
#           order_hour_of_day orders_days_since_order  product_id  \
# 0                         8             First_order         196
# 1                         7                    15.0         196
# ...

# %%
df_ords_prods
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32434207   1320836   202557            17                   2
# 32434208     31526   202557            18                   5
# 32434209    758936   203436             1                   2
# 32434210   2745165   203436             2                   3
# 32434211   3093936   205420             1                   4
#
#           order_hour_of_day orders_days_since_order  product_id  \
# 0                         8             First_order         196
# 1                         7                    15.0         196
# ...

# %%
result2 = []
for value in df_ords_prods["orders_day_of_week"]:
    if value <=1:
        result2.append("Busiest days")
    elif ((value ==3) or (value ==4)):
        result2.append("Least busiest days")  
    else:
        result2.append("Regularly busy")

# %%
df_ords_prods['busiest_days'] = result2

# %% [markdown]
# ## So I just added an operator and a less than value to make the code easier to write. I crossed check it and returned these results.

# %%
df_ords_prods['busiest_days'].value_counts()
# Out:
# busiest_days
# Regularly busy        12927461
# Busiest days          11875462
# Least busiest days     7631289
# Name: count, dtype: int64

# %%
df_ords_prods.tail()
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32434207   1320836   202557            17                   2
# 32434208     31526   202557            18                   5
# 32434209    758936   203436             1                   2
# 32434210   2745165   203436             2                   3
# 32434211   3093936   205420             1                   4
#
#           order_hour_of_day orders_days_since_order  product_id  \
# 32434207                 15                     1.0       43553
# 32434208                 11                     3.0       43553
# 32434209                  7             First_order       42338
# 32434210                  5                    15.0       42338
# 32434211                 14             First_order       28818
#
#           add_to_cart_order  reordered                   product_name  \
# 32434207                  2          1            Orange Energy Shots
# ...

# %%
df_ords_prods['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 10    2764390
# 11    2738585
# 14    2691563
# 15    2664522
# 13    2663272
# 12    2620800
# 16    2537469
# 9     2456661
# 17    2089452
# 8     1719952
# 18    1637922
# 19    1259382
# 20     977017
# 7      891928
# 21     796362
# 22     634737
# 23     402612
# 6      290770
# 0      218942
# 1      115786
# 5       88057
# 2       69431
# 4       53283
# 3       51317
# Name: count, dtype: int64

# %%
# I was trying to iterate a list and call the if statement from a list but I got knowwhere

# %%
Most_orders = [10,11,14,15,13,12,16,9]

# %%
Average_orders = [17,8,18,19,20,7,21,22]

# %%
Fewest_orders = [23,6,0,1,5,2,4,3]

# %%
# What i ultimately ended up doing was just writing a clever math code to cut down the lines.

# %%
result3 = []
for value in df_ords_prods["order_hour_of_day"]:
    if ((value >= 9) and (value <= 16)):
        result3.append("Most_orders")
    elif ((value >= 17) and (value<= 22) or (value>= 7) and (value<= 8)):
        result3.append("Average_orders ")  
    else:
        result3.append("Fewest_orders")

# %%
I then checked the list I made

# %%
result3
# Out:
# ['Average_orders ',
#  'Average_orders ',
#  'Most_orders',
#  'Average_orders ',
#  'Most_orders',
#  'Average_orders ',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders ',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders ',
#  'Most_orders',
#  'Average_orders ',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders ',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders ',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
# ...

# %%
# I then added the column to the table

# %%
df_ords_prods['busiest_times'] = result3

# %%
df_ords_prods['busiest_times'].value_counts()
# Out:
# busiest_times
# Most_orders        21137262
# Average_orders     10006752
# Fewest_orders       1290198
# Name: count, dtype: int64

# %%
df_ords_prods.to_pickle(os.path.join(path_orig, '02 Data','Prepared Data', 'df_ords_prods_Busy.pkl'))
