# %% [markdown]
# # Merging

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## I like to create different paths to not complicate the code as much

# %%
path1 = r'Desktop/CF/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_combined.pkl'

# %%
path2 = r'Desktop/CF/Achievement 4/Instacart Basket Analysis/02 Data/Prepared Data/df_prods_clean_no_dups.csv'

# %%
path_orig =r'Desktop/CF/Achievement 4/Instacart Basket Analysis'

# %%
df_prods =pd.read_csv(os.path.join(path2), index_col = False)

# %%
# this was me calling the pickle file into the notebook

# %%
df_o_p = pd.read_pickle(os.path.join(path1))

# %%
df_o_p.shape
# Out:
# (32434489, 10)

# %%
df_o_p
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           order_hour_of_day orders_days_since_order  product_id  \
# 0                         8             First_order         196
# 1                         8             First_order       14084
# ...

# %%
# I was havign issues merging the two df's. I then did some research and found that the merge cell was the same So I dropped it.

# %%
df_o_p = df_o_p.drop(columns =['_merge'])

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
# I wanted to make sure it fit

# %%
pd.merge(df_o_p,df_prods, on = ['product_id'], indicator = True)
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32434207   1320836   202557            17                   2
# 32434208     31526   202557            18                   5
# 32434209    758936   203436             1                   2
# 32434210   2745165   203436             2                   3
# 32434211   3093936   205420             1                   4
#
#           order_hour_of_day orders_days_since_order  product_id  \
# 0                         8             First_order         196
# 1                         7                    15.0         196
# ...

# %%
df_ords_prods_merge = df_o_p.merge(df_prods, on = ['product_id'], indicator = True)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#   orders_days_since_order  product_id  add_to_cart_order  reordered  \
# 0             First_order         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %%
df_ords_prods_merge.to_pickle(os.path.join(path_orig, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
